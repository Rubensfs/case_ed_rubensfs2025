# %% [markdown]
# # ============================================================
# # GOLD – Consolidação dos Metadados TerraBrasilis
# # ============================================================

# %%
from pyspark.sql import functions as F

# ================================================================
# 1. Parâmetros
# ================================================================
schema_in      = dbutils.widgets.get("schema_in")
schema_out     = dbutils.widgets.get("schema_out")
table_in       = dbutils.widgets.get("table_in")
table_out      = dbutils.widgets.get("table_out")

silver_table = f"{schema_in}.e_{table_in}"

print("Lendo Silver:", silver_table)

# %%
# ================================================================
# 2. Identificar partição mais recente
# ================================================================
max_dt = (
    spark.table(silver_table)
    .select(F.max("data_ref_carga").alias("max_date"))
    .collect()[0]["max_date"]
)

if not max_dt:
    dbutils.notebook.exit("NO_DATA")

print("Partição mais recente:", max_dt)

# %%
# ================================================================
# 3. Ler partição
# ================================================================
df = (
    spark.table(silver_table)
    .filter(F.col("data_ref_carga") == max_dt)
)

# %%
# ================================================================
# 4. Métricas Geoespaciais
# ================================================================
df = df.withColumn(
    "bbox_area_km2",
    F.when(
        F.col("northBoundLatitude").isNotNull(),
        (F.abs(F.col("northBoundLatitude") - F.col("southBoundLatitude")) *
         F.abs(F.col("eastBoundLongitude") - F.col("westBoundLongitude")) *
         111 * 111)
    )
)

df = df.withColumn(
    "bbox_center_lat",
    (F.col("northBoundLatitude") + F.col("southBoundLatitude")) / 2
)

df = df.withColumn(
    "bbox_center_lon",
    (F.col("eastBoundLongitude") + F.col("westBoundLongitude")) / 2
)

# %%
# ================================================================
# 5. Keywords / Emails
# ================================================================
df = df.withColumn(
    "all_keywords",
    F.expr("filter(keywords, x -> x is not null)")
)

df = df.withColumn(
    "keyword_count",
    F.size("all_keywords")
)

df = df.withColumn(
    "all_emails",
    F.expr("filter(emails, x -> x is not null)")
)

df = df.withColumn(
    "email_count",
    F.size("all_emails")
)

df = df.withColumn(
    "first_email",
    F.expr("element_at(all_emails,1)")
)

# %%
# ================================================================
# 6. Features analíticas
# ================================================================
df = df.withColumn(
    "dataset_age_days",
    F.datediff(F.current_date(), F.col("publication_date"))
)

df = df.withColumn(
    "has_bbox",
    F.col("bbox_area_km2").isNotNull()
)

df = df.withColumn(
    "has_keywords",
    F.col("keyword_count") > 0
)

# %%
# ================================================================
# 7. Quality Score
# ================================================================
df = df.withColumn(
    "quality_score",
    (
        F.when(F.col("title").isNotNull(),1).otherwise(0) +
        F.when(F.col("abstract").isNotNull(),1).otherwise(0) +
        F.when(F.col("publication_date").isNotNull(),1).otherwise(0) +
        F.when(F.col("keyword_count") > 0,1).otherwise(0) +
        F.when(F.col("first_email").isNotNull(),1).otherwise(0) +
        F.when(F.col("bbox_area_km2").isNotNull(),1).otherwise(0)
    )
)

# %%
# ================================================================
# 8. Dataset final GOLD
# ================================================================
df_gold = df.select(
    "uuid_metadata",
    "data_ref_carga",
    "title",
    "abstract",
    "publication_date",
    "dataset_age_days",
    "bbox_area_km2",
    "bbox_center_lat",
    "bbox_center_lon",
    "keyword_count",
    "email_count",
    "first_email",
    "quality_score"
)

# %%
# ================================================================
# 9. Gravar GOLD
# ================================================================
gold_table = f"{schema_out}.e_{table_out}"

(
    df_gold.write
        .format("delta")
        .mode("overwrite")
        .option("overwriteSchema","true")
        .saveAsTable(gold_table)
)

print("✔ GOLD gravada:", gold_table)
dbutils.notebook.exit("SUCCESS")
