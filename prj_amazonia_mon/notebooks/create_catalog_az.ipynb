# %%
# Databricks notebook source
# ================================================================
# 01_setup - Criação de catálogo, schema e pastas
# ================================================================

# MAGIC %sql
# MAGIC CREATE CATALOG IF NOT EXISTS amazonia_catalog;
# MAGIC CREATE SCHEMA IF NOT EXISTS amazonia_catalog.bronze;

dbutils.fs.mkdirs("dbfs:/mnt/amazonia/raw/xml/")
dbutils.fs.mkdirs("dbfs:/mnt/amazonia/bronze/xml/")
