# %% [markdown]
# #Criação de estrutura sem Unity Catalog

# %% [markdown]
# # Criação da estrutura de diretórios e schemas

# %% [markdown]
# 📁 1 — Criar diretórios RAW no DBFS

# %%
dbutils.fs.mkdirs("dbfs:/FileStore/datamasters/raw/raw_inpe")
dbutils.fs.mkdirs("dbfs:/FileStore/datamasters/raw/raw_tbra")

display(dbutils.fs.ls("dbfs:/FileStore/datamasters/raw"))

# %% [markdown]
# 🗄️ 2 — Criar schemas RAW

# %%
# %sql
CREATE DATABASE IF NOT EXISTS raw;

# %% [markdown]
# 🥉 3 — Criar schemas BRONZE

# %%
spark.sql("CREATE DATABASE IF NOT EXISTS b_inep")

spark.sql("USE b_inep")

spark.sql("SELECT current_database()").show()

# %% [markdown]
# 🥈 4 — Criar schemas SILVER

# %%
spark.sql("CREATE DATABASE IF NOT EXISTS s_inep")

spark.sql("USE s_inep")

spark.sql("SELECT current_database()").show()

# %% [markdown]
# 🥇 5 — Criar schemas GOLD

# %%
spark.sql("CREATE DATABASE IF NOT EXISTS g_inep")

spark.sql("USE g_inep")

spark.sql("SELECT current_database()").show()

# %% [markdown]
# 6 — Schemas TerraBrasilis

# %%
spark.sql("CREATE DATABASE IF NOT EXISTS b_tbra")
spark.sql("CREATE DATABASE IF NOT EXISTS s_tbra")
spark.sql("CREATE DATABASE IF NOT EXISTS g_tbra")
