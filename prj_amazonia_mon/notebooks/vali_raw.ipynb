# %%
raw_path = "/Volumes/datamasters/raw/raw_inpe"

df_raw = (spark.read
          .option("header", "true")
          .option("inferSchema", "true")
          .csv(f"{raw_path}/*.csv"))

display(df_raw.limit(10))
