# %%
import os
os.path.exists("/Volumes/datamasters/raw/raw_inpe/INPE_FireRiskModel_2.2_Precipitation_20251009.nc")

# %%
print(spark.read.format("binaryFile").option("pathGlobFilter", "*.nc").load("file:/Volumes/datamasters/raw/raw_inpe").inputFiles())
